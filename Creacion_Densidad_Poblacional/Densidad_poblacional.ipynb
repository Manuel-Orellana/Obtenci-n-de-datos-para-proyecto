# %%
"Fuente densidad problacional = https://www.censoecuador.gob.ec/wp-content/uploads/2023/10/2022_CPV_NACIONAL_DENSIDAD_POBLACIONAL.xlsx"
# Out:
# 'Fuente densidad problacional = https://www.censoecuador.gob.ec/wp-content/uploads/2023/10/2022_CPV_NACIONAL_DENSIDAD_POBLACIONAL.xlsx'

# %%
import pandas as pd
df_densidad_poblacional = pd.read_csv(filepath_or_buffer="2022_CPV_NACIONAL_DENSIDAD_POBLACIONAL (1).csv", sep=";", usecols= ["Provincia", "Cantón", "Parroquia", "Densidad Poblacional"])
df_densidad_poblacional.head()
# Out:
#   Provincia  Cantón Parroquia  Densidad Poblacional
# 0     AZUAY  CUENCA    CUENCA                 5.044
# 1     AZUAY  CUENCA     BAÑOS                87.000
# 2     AZUAY  CUENCA     CUMBE                86.000
# 3     AZUAY  CUENCA   CHAUCHA                 5.000
# 4     AZUAY  CUENCA     CHECA                29.000

# %%
df_densidad_poblacional.to_csv("densidad_POBLACIONAL_BASE.csv")
